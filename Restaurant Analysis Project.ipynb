# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\n tech\Desktop\Jupyter Notebook\Restaurant_revenue (1).csv")

# %%
df.head()
# Out:
#    Number_of_Customers  Menu_Price  Marketing_Spend Cuisine_Type  \
# 0                   61   43.117635        12.663793     Japanese
# 1                   24   40.020077         4.577892      Italian
# 2                   81   41.981485         4.652911     Japanese
# 3                   70   43.005307         4.416053      Italian
# 4                   30   17.456199         3.475052      Italian
#
#    Average_Customer_Spending  Promotions  Reviews  Monthly_Revenue
# 0                  36.236133           0       45       350.912040
# 1                  17.952562           0       36       221.319091
# 2                  22.600420           1       91       326.529763
# 3                  18.984098           1       59       348.190573
# 4                  12.766143           1       30       185.009121

# %%
df.tail()
# Out:
#      Number_of_Customers  Menu_Price  Marketing_Spend Cuisine_Type  \
# 995                   73   41.307842        12.122931     Japanese
# 996                   31   20.615496         5.822885      Mexican
# 997                   69   17.110656         4.141898     Japanese
# 998                   73   37.664722         3.046556     Japanese
# 999                   81   34.722067        17.989104      Italian
#
#      Average_Customer_Spending  Promotions  Reviews  Monthly_Revenue
# 995                  19.033585           1       40       249.312034
# 996                  17.040990           0       57       110.228767
# 997                  44.649315           0       55       312.212552
# 998                  27.767358           0       23       272.482204
# 999                  15.482112           1       72       379.973072

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Number_of_Customers        1000 non-null   int64
#  1   Menu_Price                 1000 non-null   float64
#  2   Marketing_Spend            1000 non-null   float64
#  3   Cuisine_Type               1000 non-null   object
#  4   Average_Customer_Spending  1000 non-null   float64
#  5   Promotions                 1000 non-null   int64
#  6   Reviews                    1000 non-null   int64
#  7   Monthly_Revenue            1000 non-null   float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# Number_of_Customers          0
# Menu_Price                   0
# Marketing_Spend              0
# Cuisine_Type                 0
# Average_Customer_Spending    0
# Promotions                   0
# Reviews                      0
# Monthly_Revenue              0
# dtype: int64

# %%
df.describe()
# Out:
#        Number_of_Customers   Menu_Price  Marketing_Spend  \
# count          1000.000000  1000.000000      1000.000000
# mean             53.271000    30.219120         9.958726
# std              26.364914    11.278760         5.845586
# min              10.000000    10.009501         0.003768
# 25%              30.000000    20.396828         4.690724
# 50%              54.000000    30.860614        10.092047
# 75%              74.000000    39.843868        14.992436
# max              99.000000    49.974140        19.994276
#
#        Average_Customer_Spending   Promotions      Reviews  Monthly_Revenue
# count                1000.000000  1000.000000  1000.000000      1000.000000
# mean                   29.477085     0.497000    49.837000       268.724172
# std                    11.471686     0.500241    29.226334       103.982950
# min                    10.037177     0.000000     0.000000       -28.977809
# ...

# %%
df.head()
# Out:
#    Number_of_Customers  Menu_Price  Marketing_Spend Cuisine_Type  \
# 0                   61   43.117635        12.663793     Japanese
# 1                   24   40.020077         4.577892      Italian
# 2                   81   41.981485         4.652911     Japanese
# 3                   70   43.005307         4.416053      Italian
# 4                   30   17.456199         3.475052      Italian
#
#    Average_Customer_Spending  Promotions  Reviews  Monthly_Revenue
# 0                  36.236133           0       45       350.912040
# 1                  17.952562           0       36       221.319091
# 2                  22.600420           1       91       326.529763
# 3                  18.984098           1       59       348.190573
# 4                  12.766143           1       30       185.009121

# %%
sns.distplot(df['Monthly_Revenue'])
# Out:
# C:\Users\n tech\AppData\Local\Temp\ipykernel_5620\1895901797.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Monthly_Revenue'])
# <Axes: xlabel='Monthly_Revenue', ylabel='Density'>

# %%
sns.jointplot( x='Number_of_Customers', y='Monthly_Revenue', data=df, kind='reg')

# %%
df.boxplot(column=['Average_Customer_Spending', 'Monthly_Revenue'])
# Out:
# <Axes: >

# %%
mapping = {'Japanese': 0, 'American': 1, 'Mexican': 2, 'Italian':3}
df['Cuisine_Type'] = df['Cuisine_Type'].map(mapping)

df.head()
# Out:
#    Number_of_Customers  Menu_Price  Marketing_Spend  Cuisine_Type  \
# 0                   61   43.117635        12.663793             0
# 1                   24   40.020077         4.577892             3
# 2                   81   41.981485         4.652911             0
# 3                   70   43.005307         4.416053             3
# 4                   30   17.456199         3.475052             3
#
#    Average_Customer_Spending  Promotions  Reviews  Monthly_Revenue
# 0                  36.236133           0       45       350.912040
# 1                  17.952562           0       36       221.319091
# 2                  22.600420           1       91       326.529763
# 3                  18.984098           1       59       348.190573
# 4                  12.766143           1       30       185.009121

# %%
df.corr()
# Out:
#                            Number_of_Customers  Menu_Price  Marketing_Spend  \
# Number_of_Customers                   1.000000    0.033470        -0.007024
# Menu_Price                            0.033470    1.000000         0.016319
# Marketing_Spend                      -0.007024    0.016319         1.000000
# Cuisine_Type                         -0.018042   -0.029550        -0.028818
# Average_Customer_Spending            -0.013898    0.020808        -0.058586
# Promotions                            0.058693    0.022068        -0.041838
# Reviews                              -0.010140    0.003792        -0.031470
# Monthly_Revenue                       0.745239    0.259579         0.269929
#
#                            Cuisine_Type  Average_Customer_Spending  \
# Number_of_Customers           -0.018042                  -0.013898
# Menu_Price                    -0.029550                   0.020808
# Marketing_Spend               -0.028818                  -0.058586
# ...

# %%
sns.pairplot(df, hue='Cuisine_Type',palette='bright')

# %%
sns.countplot(df,x='Reviews',palette='Paired')
# Out:
# C:\Users\n tech\AppData\Local\Temp\ipykernel_5620\910894294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Reviews',palette='Paired')
# <Axes: xlabel='Reviews', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Number_of_Customers        1000 non-null   int64
#  1   Menu_Price                 1000 non-null   float64
#  2   Marketing_Spend            1000 non-null   float64
#  3   Cuisine_Type               1000 non-null   int64
#  4   Average_Customer_Spending  1000 non-null   float64
#  5   Promotions                 1000 non-null   int64
#  6   Reviews                    1000 non-null   int64
#  7   Monthly_Revenue            1000 non-null   float64
# dtypes: float64(4), int64(4)
# memory usage: 62.6 KB

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='Number_of_Customers',y='Monthly_Revenue',data=df ,hue='Cuisine_Type',jitter=True, dodge=True,palette='bright')
# Out:
# <Axes: xlabel='Number_of_Customers', ylabel='Monthly_Revenue'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Number_of_Customers        1000 non-null   int64
#  1   Menu_Price                 1000 non-null   float64
#  2   Marketing_Spend            1000 non-null   float64
#  3   Cuisine_Type               1000 non-null   int64
#  4   Average_Customer_Spending  1000 non-null   float64
#  5   Promotions                 1000 non-null   int64
#  6   Reviews                    1000 non-null   int64
#  7   Monthly_Revenue            1000 non-null   float64
# dtypes: float64(4), int64(4)
# memory usage: 62.6 KB

# %%
sns.violinplot(x='Cuisine_Type',y='Monthly_Revenue',data=df)

sns.stripplot(x='Cuisine_Type',y='Monthly_Revenue',data=df,color='black')
# Out:
# <Axes: xlabel='Cuisine_Type', ylabel='Monthly_Revenue'>

# %%
sns.violinplot(x='Cuisine_Type',y='Monthly_Revenue',data=df,hue='Cuisine_Type',split=True,palette='bright')
# Out:
# <Axes: xlabel='Cuisine_Type', ylabel='Monthly_Revenue'>
